# %% [markdown]
# ## **Matplotlib**

# %% [markdown]
# ### 绘图接口
# Pyplot接口

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave")
plt.show()

# %% [markdown]
# ### 面向对象接口

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("Sine Wave")
plt.show()

# %% [markdown]
# ### 基本绘图流程

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig,ax = plt.subplots(figsize=(10,6))

ax.plot(x, y1, label='sin(x)')
ax.plot(x, y2, label='cos(x)')

ax.set_title('Trigonometric Functions', fontsize=16)
ax.set_xlabel('x', fontsize=12)
ax.set_ylabel('y', fontsize=12)
ax.legend()
ax.grid(True)

# plt.show()

# %% [markdown]
# ### 常用图表类型

# %%
fig,ax = plt.subplots()
ax.plot(x, y, color='blue', linewidth=2, linestyle='--', marker='o')

# %%
x = np.random.randn(100)
y = np.random.randn(100)
colors = np.random.rand(100)
sizes = 1000*np.random.rand(100)

fig, ax = plt.subplots()
scatter = ax.scatter(x,y,c=colors, s=sizes, alpha=0.6, cmap='viridis')
fig.colorbar(scatter, ax=ax)
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
categories = ['A', 'B', 'C', 'D']
values = [3,7,2,5]

fig, ax = plt.subplots()
ax.bar(categories, values, color='skyblue')
# Out:
# <BarContainer object of 4 artists>

# %%
data = np.random.randn(1000)

fig,ax = plt.subplots()
ax.hist(data, bins=30, color='green', alpha=0.7, edgecolor='black')
# Out:
# (array([ 1.,  2.,  4.,  8., 10., 21., 31., 46., 61., 68., 77., 85., 78.,
#         88., 86., 83., 73., 48., 46., 31., 21., 11., 11.,  4.,  1.,  0.,
#          0.,  3.,  1.,  1.]),
#  array([-3.07880708, -2.84278846, -2.60676983, -2.37075121, -2.13473258,
#         -1.89871396, -1.66269534, -1.42667671, -1.19065809, -0.95463946,
#         -0.71862084, -0.48260221, -0.24658359, -0.01056496,  0.22545366,
#          0.46147229,  0.69749091,  0.93350954,  1.16952816,  1.40554679,
#          1.64156541,  1.87758403,  2.11360266,  2.34962128,  2.58563991,
#          2.82165853,  3.05767716,  3.29369578,  3.52971441,  3.76573303,
#          4.00175166]),
#  <BarContainer object of 30 artists>)

# %%
data = [np.random.randn(100) for _ in range(4)]

fig,ax = plt.subplots()
ax.boxplot(data, labels=['Group 1', 'Group 2', 'Group 3', 'Group 4'])
# Out:
# C:\Users\22402\AppData\Local\Temp\ipykernel_27888\506231437.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=['Group 1', 'Group 2', 'Group 3', 'Group 4'])
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c88ff77390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c88ff77610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c88dbe65d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2c88ff77890>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2c88ff779d0>,
# ...
#  'means': []}

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 8))  # 2x2 网格

# axs 现在是一个 2x2 的数组
axs[0, 0].plot(x, y1)
axs[0, 0].set_title('Plot 1')

axs[0, 1].scatter(x, y2)
axs[0, 1].set_title('Plot 2')

axs[1, 0].bar(categories, values)
axs[1, 0].set_title('Plot 3')

axs[1, 1].hist(data, bins=20)
axs[1, 1].set_title('Plot 4')

plt.tight_layout()  # 自动调整子图间距，防止重叠
plt.show()
